# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
from numpy.random import normal
M = 100000
u = np.random.uniform(size=M)

plt.hist(u)
plt.title("Uniform Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
from scipy.stats import norm

# %%
norm.ppf?

# %%
z = norm.ppf(u)

# %%
plt.hist(z)
plt.title("Uniform Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
M = 100
u = np.random.uniform(size = M)
uhat = np.zeros((M,))

for i in range(M):
    uhat[i] = (u[i] + i) / M

# %%
uhat
# Out:
# array([ 0.00997185,  0.01374   ,  0.02966856,  0.03740803,  0.04927819,
#         0.05560323,  0.06378401,  0.07700211,  0.08496121,  0.09319388,
#         0.10796683,  0.117716  ,  0.12371707,  0.13870631,  0.14848735,
#         0.15826118,  0.16202066,  0.17080419,  0.1860915 ,  0.19526223,
#         0.20894882,  0.21755367,  0.22513825,  0.23371232,  0.24076418,
#         0.25962997,  0.26712629,  0.276434  ,  0.28625443,  0.29869002,
#         0.30091293,  0.3127228 ,  0.32709707,  0.3362069 ,  0.34252745,
#         0.35720923,  0.36128374,  0.3705674 ,  0.38926371,  0.39752375,
#         0.40308988,  0.41160583,  0.42450821,  0.43951205,  0.44055806,
#         0.45267213,  0.46964102,  0.47219043,  0.48937937,  0.49366904,
#         0.5026282 ,  0.51243953,  0.52273538,  0.5305331 ,  0.54320933,
#         0.55661286,  0.56323189,  0.57001431,  0.58044656,  0.59611844,
#         0.60913108,  0.61175944,  0.62529979,  0.63187857,  0.64601114,
#         0.65836567,  0.66658827,  0.67893789,  0.68642158,  0.69053211,
#         0.70315495,  0.71650092,  0.72727887,  0.73599954,  0.7429827 ,
#         0.75463327,  0.76270286,  0.77222119,  0.78474434,  0.79927068,
#         0.80623215,  0.81527761,  0.8249074 ,  0.8368695 ,  0.84176545,
#         0.85355392,  0.86903215,  0.87470063,  0.88324007,  0.89836747,
#         0.9043695 ,  0.91165576,  0.92521033,  0.93578884,  0.94274938,
#         0.95937139,  0.96630494,  0.97822138,  0.9847767 ,  0.99819092])

# %%
plt.hist(uhat)
plt.title("Stratified Uniform Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
z = norm.ppf(uhat)
plt.hist(z)
plt.title("Stratified Normal Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
M = 1000
u = np.random.uniform(size = M)
uhat = np.zeros((M,))

i = np.arange(M)
uhat = (u + i) / M

spot = 41.0
strike = 40.0
expiry = 1.0
rate = 0.08
sigma = 0.30

## The main simulation loop
z = norm.ppf(uhat)
spotT = np.empty((M, ))
callT = np.empty((M, ))
spotT = spot * np.exp((rate - 0.5 * sigma * sigma)* expiry + sigma * np.sqrt(expiry) * z)
callT = np.maximum(spotT - strike, 0.0)
price = np.exp(-rate * expiry) * callT.mean()
print("The Call Price is: {0:.3f}".format(price))
# Out:
# The Call Price is: 6.958
